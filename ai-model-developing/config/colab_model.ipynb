# %% [markdown]
# Zip your:  images/ + labels/ + data.yaml to .zip file (for exampe dataset.zip)

# %% [markdown]
# Upload .zip file to your Google Colab notebook

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install ultralytics

# %%
import zipfile
import os

with zipfile.ZipFile('model1.3.zip', 'r') as zip_ref: # your .zip
    zip_ref.extractall('dataset')

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')

model.train(
    data='dataset/dataset.yaml',
    epochs=50,
    imgsz=640,
    device='cuda'
)

# %% [markdown]
# Zip runs/ (results folder) for easier download and later use

# %%
import shutil

shutil.make_archive("runs", 'zip', "runs")

# %%
from google.colab import files
files.download("runs.zip")
